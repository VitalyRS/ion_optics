# %%
import pandas as pd

# %%
folder1="con_campo_entero/6"
file1=folder1+"/"+"test11_01.csv"
#file1="test11.csv"

bd1=pd.read_csv(file1,sep="\t")
print bd1.head(5)
#bd1[bd1.ion_px_mm>95]
bd=bd1[bd1.iloc[:,1]>80]
print "ion_num1:",bd[bd.ion_number==1].shape[0],"ion_num2:",bd[bd.ion_number==2].shape[0],"ion_num3:",bd[bd.ion_number==3].shape[0]
# Out:
#    ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  el3  \
# 0            0.057297   63.157963   -2.869865    9.787945 -0.9 -0.3 -0.6   -1
# 1            0.057297   63.157963   -2.869865    9.787945 -0.9 -0.3 -0.6   -1
# 2            0.059531   72.875235    5.290201    8.720881 -0.9 -0.3 -0.6   -1
# 3            0.059531   72.875235    5.290201    8.720881 -0.9 -0.3 -0.6   -1
# 4            0.058741   66.308736   -3.676004    9.514567 -0.9 -0.3 -0.6   -1
#
#    el4  el5  ion_number  ion_color
# 0   -1   -2           1        NaN
# 1   -1   -2           1        NaN
# 2   -1   -2           2        NaN
# 3   -1   -2           2        NaN
# 4   -1   -1           1        NaN
# ion_num1: 226 ion_num2: 1316 ion_num3: 8802

# %%
bd=bd[abs(bd.iloc[:,2])<10]
bd=bd[abs(bd.iloc[:,3])<10]
bd
# Out:
#        ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  \
# 14               0.066103   83.464058   -3.686093    9.510663 -0.9 -0.3 -0.6
# 15               0.066103   83.464058   -3.686093    9.510663 -0.9 -0.3 -0.6
# 18               0.065388   82.771803   -5.359913    8.678210 -0.9 -0.3 -0.6
# 19               0.065388   82.771803   -5.359913    8.678210 -0.9 -0.3 -0.6
# 22               0.064418   81.713604   -6.540016    7.827400 -0.9 -0.3 -0.6
# 23               0.064418   81.713604   -6.540016    7.827400 -0.9 -0.3 -0.6
# 26               0.063396   80.578359   -7.384489    7.036286 -0.9 -0.3 -0.6
# 27               0.063396   80.578359   -7.384489    7.036286 -0.9 -0.3 -0.6
# 32               0.065284   80.003893   -8.438888    5.729325 -0.9 -0.3 -0.6
# 33               0.065284   80.003893   -8.438888    5.729325 -0.9 -0.3 -0.6
# 36               0.065580   80.849476   -8.814639    5.132459 -0.9 -0.3 -0.6
# 37               0.065580   80.849476   -8.814639    5.132459 -0.9 -0.3 -0.6
# 40               0.065775   81.527306   -9.124147    4.559599 -0.9 -0.3 -0.6
# 41               0.065775   81.527306   -9.124147    4.559599 -0.9 -0.3 -0.6
# 58               0.068081   87.794643   -2.457831    9.899448 -0.9 -0.3 -0.6
# 59               0.068081   87.794643   -2.457831    9.899448 -0.9 -0.3 -0.6
# 62               0.067257   86.731600   -4.646640    9.080129 -0.9 -0.3 -0.6
# 63               0.067257   86.731600   -4.646640    9.080129 -0.9 -0.3 -0.6
# 66               0.065997   85.083772   -6.122995    8.157753 -0.9 -0.3 -0.6
# 67               0.065997   85.083772   -6.122995    8.157753 -0.9 -0.3 -0.6
# 70               0.064677   83.382046   -7.144642    7.279704 -0.9 -0.3 -0.6
# 71               0.064677   83.382046   -7.144642    7.279704 -0.9 -0.3 -0.6
# 72               0.064796   80.096390   -7.621800    6.778508 -0.9 -0.3 -0.6
# 73               0.064796   80.096390   -7.621800    6.778508 -0.9 -0.3 -0.6
# 74               0.063422   81.793468   -7.866569    6.492849 -0.9 -0.3 -0.6
# 75               0.063422   81.793468   -7.866569    6.492849 -0.9 -0.3 -0.6
# 76               0.065230   81.098173   -8.131514    6.157799 -0.9 -0.3 -0.6
# 77               0.065230   81.098173   -8.131514    6.157799 -0.9 -0.3 -0.6
# 78               0.062271   80.365749   -8.387545    5.804230 -0.9 -0.3 -0.6
# 79               0.062271   80.365749   -8.387545    5.804230 -0.9 -0.3 -0.6
# ...                   ...         ...         ...         ...  ...  ...  ...
# 34838            0.077543  102.917167   -9.126955   -4.553975  0.6  0.3 -0.6
# 34839            0.077543  102.917167   -9.126955   -4.553975  0.6  0.3 -0.6
# 34844            0.079368  106.854395   -9.216777   -4.369328  0.6  0.3 -0.6
# 34845            0.079368  106.854395   -9.216777   -4.369328  0.6  0.3 -0.6
# 34850            0.080999  110.486853   -9.305377   -4.177315  0.6  0.3 -0.6
# 34851            0.080999  110.486853   -9.305377   -4.177315  0.6  0.3 -0.6
# 34856            0.082565  113.827977   -9.391297   -3.980394  0.6  0.3 -0.6
# 34857            0.082565  113.827977   -9.391297   -3.980394  0.6  0.3 -0.6
# 34862            0.084021  116.921217   -9.473417   -3.780790  0.6  0.3 -0.6
# 34863            0.084021  116.921217   -9.473417   -3.780790  0.6  0.3 -0.6
# 34868            0.085378  119.783885   -9.551022   -3.580219  0.6  0.3 -0.6
# 34869            0.085378  119.783885   -9.551022   -3.580219  0.6  0.3 -0.6
# 34874            0.086639  122.433258   -9.623625   -3.380213  0.6  0.3 -0.6
# 34875            0.086639  122.433258   -9.623625   -3.380213  0.6  0.3 -0.6
# 34880            0.066554   85.238449   -8.828362   -5.108819  0.6  0.3 -0.6
# 34881            0.066554   85.238449   -8.828362   -5.108819  0.6  0.3 -0.6
# 34886            0.069651   90.089926   -8.888808   -5.002909  0.6  0.3 -0.6
# 34887            0.069651   90.089926   -8.888808   -5.002909  0.6  0.3 -0.6
# 34892            0.074376   98.224969   -8.932664   -4.924176  0.6  0.3 -0.6
# 34893            0.074376   98.224969   -8.932664   -4.924176  0.6  0.3 -0.6
# 34898            0.076500  102.778354   -9.024269   -4.754215  0.6  0.3 -0.6
# 34899            0.076500  102.778354   -9.024269   -4.754215  0.6  0.3 -0.6
# 34904            0.078367  106.782534   -9.120166   -4.567556  0.6  0.3 -0.6
# 34905            0.078367  106.782534   -9.120166   -4.567556  0.6  0.3 -0.6
# 34910            0.080204  110.474342   -9.216977   -4.368905  0.6  0.3 -0.6
# 34911            0.080204  110.474342   -9.216977   -4.368905  0.6  0.3 -0.6
# 34916            0.081837  113.931804   -9.312018   -4.162490  0.6  0.3 -0.6
# 34917            0.081837  113.931804   -9.312018   -4.162490  0.6  0.3 -0.6
# 34922            0.083408  117.151932   -9.404446   -3.949227  0.6  0.3 -0.6
# 34923            0.083408  117.151932   -9.404446   -3.949227  0.6  0.3 -0.6
#
#        el3  el4  el5  ion_number  ion_color
# 14      -1   -1    1           2        NaN
# 15      -1   -1    1           2        NaN
# 18      -1   -1    2           2        NaN
# 19      -1   -1    2           2        NaN
# 22      -1   -1    3           2        NaN
# 23      -1   -1    3           2        NaN
# 26      -1   -1    4           2        NaN
# 27      -1   -1    4           2        NaN
# 32      -1   -1    6           1        NaN
# 33      -1   -1    6           1        NaN
# 36      -1   -1    7           1        NaN
# 37      -1   -1    7           1        NaN
# 40      -1   -1    8           1        NaN
# 41      -1   -1    8           1        NaN
# 58      -1    0    2           2        NaN
# 59      -1    0    2           2        NaN
# 62      -1    0    3           2        NaN
# 63      -1    0    3           2        NaN
# 66      -1    0    4           2        NaN
# 67      -1    0    4           2        NaN
# 70      -1    0    5           2        NaN
# 71      -1    0    5           2        NaN
# 72      -1    0    6           1        NaN
# 73      -1    0    6           1        NaN
# 74      -1    0    6           2        NaN
# 75      -1    0    6           2        NaN
# 76      -1    0    7           1        NaN
# 77      -1    0    7           1        NaN
# 78      -1    0    7           2        NaN
# 79      -1    0    7           2        NaN
# ...    ...  ...  ...         ...        ...
# 34838    8    7    2           3        NaN
# 34839    8    7    2           3        NaN
# 34844    8    7    3           3        NaN
# 34845    8    7    3           3        NaN
# 34850    8    7    4           3        NaN
# 34851    8    7    4           3        NaN
# 34856    8    7    5           3        NaN
# 34857    8    7    5           3        NaN
# 34862    8    7    6           3        NaN
# 34863    8    7    6           3        NaN
# 34868    8    7    7           3        NaN
# 34869    8    7    7           3        NaN
# 34874    8    7    8           3        NaN
# 34875    8    7    8           3        NaN
# 34880    8    8    1           3        NaN
# 34881    8    8    1           3        NaN
# 34886    8    8    2           3        NaN
# 34887    8    8    2           3        NaN
# 34892    8    8    3           3        NaN
# 34893    8    8    3           3        NaN
# 34898    8    8    4           3        NaN
# 34899    8    8    4           3        NaN
# 34904    8    8    5           3        NaN
# 34905    8    8    5           3        NaN
# 34910    8    8    6           3        NaN
# 34911    8    8    6           3        NaN
# 34916    8    8    7           3        NaN
# 34917    8    8    7           3        NaN
# 34922    8    8    8           3        NaN
# 34923    8    8    8           3        NaN
#
# [8990 rows x 12 columns]

# %%
newbd=bd.drop_duplicates()
newbd.index=range(newbd.shape[0])
newbd
# Out:
#        ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  \
# 0                0.059531   72.875235    5.290201    8.720881 -0.9 -0.3 -0.6
# 1                0.064270   80.150777    1.910972   10.019390 -0.9 -0.3 -0.6
# 2                0.066081   83.098475   -1.305191   10.116149 -0.9 -0.3 -0.6
# 3                0.061474   71.856726   -5.341244    8.689713 -0.9 -0.3 -0.6
# 4                0.066103   83.464058   -3.686093    9.510663 -0.9 -0.3 -0.6
# 5                0.062610   74.135738   -6.122305    8.158270 -0.9 -0.3 -0.6
# 6                0.065388   82.771803   -5.359913    8.678210 -0.9 -0.3 -0.6
# 7                0.063549   76.059939   -6.830483    7.575256 -0.9 -0.3 -0.6
# 8                0.064418   81.713604   -6.540016    7.827400 -0.9 -0.3 -0.6
# 9                0.064294   77.652250   -7.452992    6.963685 -0.9 -0.3 -0.6
# 10               0.063396   80.578359   -7.384489    7.036286 -0.9 -0.3 -0.6
# 11               0.064864   78.951916   -7.987630    6.343325 -0.9 -0.3 -0.6
# 12               0.062406   79.482980   -7.999623    6.328194 -0.9 -0.3 -0.6
# 13               0.065284   80.003893   -8.438888    5.729325 -0.9 -0.3 -0.6
# 14               0.061488   78.486021   -8.454692    5.705978 -0.9 -0.3 -0.6
# 15               0.065580   80.849476   -8.814639    5.132459 -0.9 -0.3 -0.6
# 16               0.060631   77.566030   -8.799611    5.158183 -0.9 -0.3 -0.6
# 17               0.065775   81.527306   -9.124147    4.559599 -0.9 -0.3 -0.6
# 18               0.059846   76.740153   -9.064094    4.677842 -0.9 -0.3 -0.6
# 19               0.061853   78.815981    5.331126    8.695924 -0.9 -0.3 -0.6
# 20               0.059760   70.467417   -3.809921    9.461739 -0.9 -0.3 -0.6
# 21               0.067297   86.610879    0.862245   10.163490 -0.9 -0.3 -0.6
# 22               0.061175   73.084153   -4.697345    9.054002 -0.9 -0.3 -0.6
# 23               0.068081   87.794643   -2.457831    9.899448 -0.9 -0.3 -0.6
# 24               0.062399   75.358864   -5.548083    8.559134 -0.9 -0.3 -0.6
# 25               0.067257   86.731600   -4.646640    9.080129 -0.9 -0.3 -0.6
# 26               0.063406   77.269815   -6.328951    7.999023 -0.9 -0.3 -0.6
# 27               0.065997   85.083772   -6.122995    8.157753 -0.9 -0.3 -0.6
# 28               0.064197   78.835844   -7.021974    7.398100 -0.9 -0.3 -0.6
# 29               0.064677   83.382046   -7.144642    7.279704 -0.9 -0.3 -0.6
# ...                   ...         ...         ...         ...  ...  ...  ...
# 11812            0.054730   71.163039   -9.702612   -3.146319  0.6  0.3 -0.6
# 11813            0.092147  130.473180   -9.980608   -2.104153  0.6  0.3 -0.6
# 11814            0.055301   72.348139   -9.757080   -2.973112  0.6  0.3 -0.6
# 11815            0.092720  131.908876  -10.000967   -2.005159  0.6  0.3 -0.6
# 11816            0.085594  118.037818   -9.612068   -3.412937  0.6  0.3 -0.6
# 11817            0.086748  120.696043   -9.673408   -3.234993  0.6  0.3 -0.6
# 11818            0.087838  123.121153   -9.729912   -3.060852  0.6  0.3 -0.6
# 11819            0.054487   71.077520   -9.562633   -3.549092  0.6  0.3 -0.6
# 11820            0.088842  125.348664   -9.781536   -2.891635  0.6  0.3 -0.6
# 11821            0.055049   72.242478   -9.628371   -3.366672  0.6  0.3 -0.6
# 11822            0.089766  127.397144   -9.828469   -2.727856  0.6  0.3 -0.6
# 11823            0.077543  102.917167   -9.126955   -4.553975  0.6  0.3 -0.6
# 11824            0.079368  106.854395   -9.216777   -4.369328  0.6  0.3 -0.6
# 11825            0.080999  110.486853   -9.305377   -4.177315  0.6  0.3 -0.6
# 11826            0.082565  113.827977   -9.391297   -3.980394  0.6  0.3 -0.6
# 11827            0.084021  116.921217   -9.473417   -3.780790  0.6  0.3 -0.6
# 11828            0.054268   71.005118   -9.408636   -3.939234  0.6  0.3 -0.6
# 11829            0.085378  119.783885   -9.551022   -3.580219  0.6  0.3 -0.6
# 11830            0.054824   72.155334   -9.486028   -3.749036  0.6  0.3 -0.6
# 11831            0.086639  122.433258   -9.623625   -3.380213  0.6  0.3 -0.6
# 11832            0.066554   85.238449   -8.828362   -5.108819  0.6  0.3 -0.6
# 11833            0.069651   90.089926   -8.888808   -5.002909  0.6  0.3 -0.6
# 11834            0.074376   98.224969   -8.932664   -4.924176  0.6  0.3 -0.6
# 11835            0.076500  102.778354   -9.024269   -4.754215  0.6  0.3 -0.6
# 11836            0.078367  106.782534   -9.120166   -4.567556  0.6  0.3 -0.6
# 11837            0.080204  110.474342   -9.216977   -4.368905  0.6  0.3 -0.6
# 11838            0.054065   70.937299   -9.241573   -4.316634  0.6  0.3 -0.6
# 11839            0.081837  113.931804   -9.312018   -4.162490  0.6  0.3 -0.6
# 11840            0.054618   72.077217   -9.330896   -4.119998  0.6  0.3 -0.6
# 11841            0.083408  117.151932   -9.404446   -3.949227  0.6  0.3 -0.6
#
#        el3  el4  el5  ion_number  ion_color
# 0       -1   -1   -2           2        NaN
# 1       -1   -1   -1           2        NaN
# 2       -1   -1    0           2        NaN
# 3       -1   -1    1           1        NaN
# 4       -1   -1    1           2        NaN
# 5       -1   -1    2           1        NaN
# 6       -1   -1    2           2        NaN
# 7       -1   -1    3           1        NaN
# 8       -1   -1    3           2        NaN
# 9       -1   -1    4           1        NaN
# 10      -1   -1    4           2        NaN
# 11      -1   -1    5           1        NaN
# 12      -1   -1    5           2        NaN
# 13      -1   -1    6           1        NaN
# 14      -1   -1    6           2        NaN
# 15      -1   -1    7           1        NaN
# 16      -1   -1    7           2        NaN
# 17      -1   -1    8           1        NaN
# 18      -1   -1    8           2        NaN
# 19      -1    0    0           2        NaN
# 20      -1    0    1           1        NaN
# 21      -1    0    1           2        NaN
# 22      -1    0    2           1        NaN
# 23      -1    0    2           2        NaN
# 24      -1    0    3           1        NaN
# 25      -1    0    3           2        NaN
# 26      -1    0    4           1        NaN
# 27      -1    0    4           2        NaN
# 28      -1    0    5           1        NaN
# 29      -1    0    5           2        NaN
# ...    ...  ...  ...         ...        ...
# 11812    8    5    7           1        NaN
# 11813    8    5    7           3        NaN
# 11814    8    5    8           1        NaN
# 11815    8    5    8           3        NaN
# 11816    8    6    4           3        NaN
# 11817    8    6    5           3        NaN
# 11818    8    6    6           3        NaN
# 11819    8    6    7           1        NaN
# 11820    8    6    7           3        NaN
# 11821    8    6    8           1        NaN
# 11822    8    6    8           3        NaN
# 11823    8    7    2           3        NaN
# 11824    8    7    3           3        NaN
# 11825    8    7    4           3        NaN
# 11826    8    7    5           3        NaN
# 11827    8    7    6           3        NaN
# 11828    8    7    7           1        NaN
# 11829    8    7    7           3        NaN
# 11830    8    7    8           1        NaN
# 11831    8    7    8           3        NaN
# 11832    8    8    1           3        NaN
# 11833    8    8    2           3        NaN
# 11834    8    8    3           3        NaN
# 11835    8    8    4           3        NaN
# 11836    8    8    5           3        NaN
# 11837    8    8    6           3        NaN
# 11838    8    8    7           1        NaN
# 11839    8    8    7           3        NaN
# 11840    8    8    8           1        NaN
# 11841    8    8    8           3        NaN
#
# [11842 rows x 12 columns]

# %%
#bd2=bd[(bd.ion_number==3) ]
bd2=bd[(bd.iloc[:,1]>80) ]
bd2.index=range(bd2.shape[0])
print bd2.shape
bd2.head()
bd2_2=bd2[bd2.ion_number==1]
bd2_2.shape
# Out:
# (8990, 12)
# (172, 12)

# %%
bd2.head(10)
# Out:
#    ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  el3  \
# 0            0.066103   83.464058   -3.686093    9.510663 -0.9 -0.3 -0.6   -1
# 1            0.066103   83.464058   -3.686093    9.510663 -0.9 -0.3 -0.6   -1
# 2            0.065388   82.771803   -5.359913    8.678210 -0.9 -0.3 -0.6   -1
# 3            0.065388   82.771803   -5.359913    8.678210 -0.9 -0.3 -0.6   -1
# 4            0.064418   81.713604   -6.540016    7.827400 -0.9 -0.3 -0.6   -1
# 5            0.064418   81.713604   -6.540016    7.827400 -0.9 -0.3 -0.6   -1
# 6            0.063396   80.578359   -7.384489    7.036286 -0.9 -0.3 -0.6   -1
# 7            0.063396   80.578359   -7.384489    7.036286 -0.9 -0.3 -0.6   -1
# 8            0.065284   80.003893   -8.438888    5.729325 -0.9 -0.3 -0.6   -1
# 9            0.065284   80.003893   -8.438888    5.729325 -0.9 -0.3 -0.6   -1
#
#    el4  el5  ion_number  ion_color
# 0   -1    1           2        NaN
# 1   -1    1           2        NaN
# 2   -1    2           2        NaN
# 3   -1    2           2        NaN
# 4   -1    3           2        NaN
# 5   -1    3           2        NaN
# 6   -1    4           2        NaN
# 7   -1    4           2        NaN
# 8   -1    6           1        NaN
# 9   -1    6           1        NaN

# %%
print bd2.shape
print bd2_2.shape
# Out:
# (741686, 12)
# (373888, 12)

# %%
bd2[bd2.iloc[:,1]<90]
# Out:
# Empty DataFrame
# Columns: [ion_time_of_flight, ion_px_mm , ion_py_mm , ion_pz_mm , bx, by, bz, el3, el4, el5, ion_number, ion_color]
# Index: []

# %%
bd2.iloc[bd2[abs(bd2.bx)<0.001].index.values,4]=0
bd2.iloc[bd2[abs(bd2.by)<0.001].index.values,5]=0
bd2.iloc[bd2[abs(bd2.bz)<0.001].index.values,6]=0

# %%
gbx,gby,gbz,gel3,gel4,gel5=[],[],[],[],[],[]
i=0
for bx,by,bz,el3,el4,el5 in zip(bd2_2.bx,bd2_2.by,bd2_2.bz,bd2_2.el3,bd2_2.el4,bd2_2.el5):
    #print bx,by,bz,el3,el4,el5
    b=bd2[(bd2.el3==el3)&(bd2.el4==el4)&(bd2.el5==el5)&(bd2.bx==bx)&(bd2.by==by)&(bd2.bz==bz)]
    #if i<10:
    #    print "---"
    #    print b.iloc[:,[1,4,5,6,7,8,9,10,11]]
    #    i=i+1
    #else:
    #    break
        
    if len(list(set(b.ion_color.values)))>2:
        #print len(list(set(b.ion_number.values)))
        #print bx,by,bz,el3,el4,el5
        #print set(b.ion_color.values)
        if abs(by)<0.01:
            by=0
        if abs(by)<0.01:
            by=0
        if abs(bz)<0.01:
            bz=0
        gbx.append(bx)
        gby.append(by)
        gbz.append(bz)
        gel3.append(el3)
        gel4.append(el4)
        gel5.append(el5)
        
datas={"bx":gbx,"by":gby,"bz":gbz,"el3":gel3,"el4":gel4,"el5":gel5}
newbd=pd.DataFrame(datas)
newbd=newbd.drop_duplicates()
newbd.index=range(newbd.shape[0])
newbd
# Out:
#      bx   by   bz  el3  el4  el5
# 0  -0.9 -0.3 -0.6   -1    0    6
# 1  -0.9 -0.3 -0.6   -1    0    7
# 2  -0.9 -0.3 -0.6   -1    1    7
# 3  -0.9 -0.3 -0.6   -1    1    8
# 4  -0.9 -0.3 -0.6   -1    3    7
# 5  -0.9 -0.3 -0.6   -1    3    8
# 6  -0.9 -0.3 -0.6   -1    4    8
# 7  -0.9 -0.3 -0.6   -1    5    8
# 8  -0.9 -0.3 -0.6    0    2    8
# 9  -0.9 -0.3 -0.6    0    3    8
# 10 -0.9 -0.3 -0.6    0    4    8
# 11 -0.9  0.3 -0.6    2   -2    6
# 12 -0.9  0.3 -0.6    2   -2    7
# 13 -0.9  0.3 -0.6    2   -2    8
# 14 -0.9  0.3 -0.6    2   -1    6
# 15 -0.9  0.3 -0.6    2   -1    7
# 16 -0.9  0.3 -0.6    2   -1    8
# 17 -0.9  0.3 -0.6    2    0    7
# 18 -0.9  0.3 -0.6    2    0    8
# 19 -0.9  0.3 -0.6    3   -2    7
# 20 -0.9  0.3 -0.6    3   -2    8
# 21 -0.9  0.3 -0.6    3   -1    7
# 22 -0.9  0.3 -0.6    3   -1    8
# 23 -0.9  0.3 -0.6    3    0    8
# 24 -0.9  0.3 -0.6    3    1    8
# 25 -0.9  0.3 -0.6    4   -2    8
# 26 -0.9  0.3 -0.6    4   -1    8
# 27 -0.9  0.3 -0.6    4    0    8
# 28 -0.9  0.3 -0.6    5   -2    8
# 29 -0.9  0.3 -0.6    6   -2    8
# 30 -0.9  0.3 -0.6    7   -2    8
# 31 -0.9  0.3 -0.6    8   -2    8
# 32 -0.6 -0.3 -0.6   -1    0    6
# 33 -0.6 -0.3 -0.6    0    2    8
# 34 -0.6 -0.3 -0.6    0    3    8
# 35 -0.6  0.3 -0.6    2   -2    7
# 36 -0.6  0.3 -0.6    2   -2    8
# 37 -0.6  0.3 -0.6    2   -1    7
# 38 -0.6  0.3 -0.6    2   -1    8
# 39 -0.6  0.3 -0.6    3   -2    8
# 40 -0.6  0.3 -0.6    3   -1    8
# 41 -0.6  0.3 -0.6    4   -2    8
# 42 -0.3 -0.3 -0.6    2   -4    8
# 43 -0.3  0.3 -0.6    2   -3    8
# 44 -0.3  0.3 -0.6    2   -2    8
# 45 -0.3  0.3 -0.6    6   -3    8
# 46  0.3 -0.3 -0.6    2   -3    8
# 47  0.3 -0.3 -0.6    2   -2    8
# 48  0.3 -0.3 -0.6    6   -3    8
# 49  0.3  0.3 -0.6    2   -4    8
# 50  0.6 -0.3 -0.6    2   -2    7
# 51  0.6 -0.3 -0.6    2   -2    8
# 52  0.6 -0.3 -0.6    2   -1    7
# 53  0.6 -0.3 -0.6    2   -1    8
# 54  0.6 -0.3 -0.6    3   -2    8
# 55  0.6 -0.3 -0.6    3   -1    8
# 56  0.6 -0.3 -0.6    4   -2    8
# 57  0.6  0.3 -0.6   -1    0    6
# 58  0.6  0.3 -0.6    0    2    8
# 59  0.6  0.3 -0.6    0    3    8

# %%
file1[19:-4]
# Out:
# 'test11'

# %%
newbd.to_csv("analyzed_test"+file1[19:-4]+"19_01_2016_01.csv",index=False,sep="\t")

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.plot(newbd.bx)

# %%
newbd[newbd.bx==0.3]
# Out:
#        bx   by   bz  el3  el4  el5
# 3631  0.3 -0.3 -0.6    2   -3    5
# 3632  0.3 -0.3 -0.6    2   -3    6
# 3633  0.3 -0.3 -0.6    2   -3    7
# 3634  0.3 -0.3 -0.6    2   -3    8
# 3635  0.3 -0.3 -0.6    2   -2    5
# 3636  0.3 -0.3 -0.6    2   -2    6
# 3637  0.3 -0.3 -0.6    2   -2    7
# 3638  0.3 -0.3 -0.6    2   -2    8
# 3639  0.3 -0.3 -0.6    2   -1   -2
# 3640  0.3 -0.3 -0.6    2   -1   -1
# 3641  0.3 -0.3 -0.6    2   -1    0
# 3642  0.3 -0.3 -0.6    2   -1    1
# 3643  0.3 -0.3 -0.6    2   -1    2
# 3644  0.3 -0.3 -0.6    2   -1    3
# 3645  0.3 -0.3 -0.6    2   -1    4
# 3646  0.3 -0.3 -0.6    2   -1    5
# 3647  0.3 -0.3 -0.6    2   -1    6
# 3648  0.3 -0.3 -0.6    2   -1    7
# 3649  0.3 -0.3 -0.6    2   -1    8
# 3650  0.3 -0.3 -0.6    2    0   -1
# 3651  0.3 -0.3 -0.6    2    0    0
# 3652  0.3 -0.3 -0.6    2    0    1
# 3653  0.3 -0.3 -0.6    2    0    2
# 3654  0.3 -0.3 -0.6    2    0    3
# 3655  0.3 -0.3 -0.6    2    0    4
# 3656  0.3 -0.3 -0.6    2    0    5
# 3657  0.3 -0.3 -0.6    2    0    6
# 3658  0.3 -0.3 -0.6    2    0    7
# 3659  0.3 -0.3 -0.6    2    0    8
# 3660  0.3 -0.3 -0.6    2    1    0
# ...   ...  ...  ...  ...  ...  ...
# 4616  0.3  0.3 -0.6    8   -2    8
# 4617  0.3  0.3 -0.6    8   -1    7
# 4618  0.3  0.3 -0.6    8   -1    8
# 4619  0.3  0.3 -0.6    8    0    0
# 4620  0.3  0.3 -0.6    8    2    8
# 4621  0.3  0.3 -0.6    8    3    8
# 4622  0.3  0.3 -0.6    8    4    7
# 4623  0.3  0.3 -0.6    8    4    8
# 4624  0.3  0.3 -0.6    8    5    5
# 4625  0.3  0.3 -0.6    8    5    6
# 4626  0.3  0.3 -0.6    8    5    7
# 4627  0.3  0.3 -0.6    8    5    8
# 4628  0.3  0.3 -0.6    8    6    4
# 4629  0.3  0.3 -0.6    8    6    5
# 4630  0.3  0.3 -0.6    8    6    6
# 4631  0.3  0.3 -0.6    8    6    7
# 4632  0.3  0.3 -0.6    8    6    8
# 4633  0.3  0.3 -0.6    8    7    3
# 4634  0.3  0.3 -0.6    8    7    4
# 4635  0.3  0.3 -0.6    8    7    5
# 4636  0.3  0.3 -0.6    8    7    6
# 4637  0.3  0.3 -0.6    8    7    7
# 4638  0.3  0.3 -0.6    8    7    8
# 4639  0.3  0.3 -0.6    8    8    2
# 4640  0.3  0.3 -0.6    8    8    3
# 4641  0.3  0.3 -0.6    8    8    4
# 4642  0.3  0.3 -0.6    8    8    5
# 4643  0.3  0.3 -0.6    8    8    6
# 4644  0.3  0.3 -0.6    8    8    7
# 4645  0.3  0.3 -0.6    8    8    8
#
# [1015 rows x 6 columns]
