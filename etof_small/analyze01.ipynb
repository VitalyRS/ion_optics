# %%
import pandas as pd

# %%
folder1="con_campo_entero"
folder2="sin_campo_entero"
file1=folder1+"/"+"test03.csv"
bd1=pd.read_csv(file1,sep="\t")
print bd1.head(5)
#bd1[bd1.ion_px_mm>95]
bd1[bd1.iloc[:,1]>93]
# Out:
#    ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  el3  \
# 0            0.029626   29.862833    0.871108    5.037811 -0.9 -0.9 -0.9    0
# 1            0.029626   29.862833    0.871108    5.037811 -0.9 -0.9 -0.9    0
# 2            0.029626   29.862776    0.871116    5.037797 -0.9 -0.9 -0.9    0
# 3            0.029626   29.862776    0.871116    5.037797 -0.9 -0.9 -0.9    0
# 4            0.029626   29.862718    0.871125    5.037783 -0.9 -0.9 -0.9    0
#
#    el4  el5
# 0    0    0
# 1    0    0
# 2    0    1
# 3    0    1
# 4    0    2
#        ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx  \
# 2704             0.067774   93.007522   -2.583045    9.554172 -0.9
# 2705             0.067774   93.007522   -2.583045    9.554172 -0.9
# 2706             0.066538   93.146604   -3.373424    9.025255 -0.9
# 2707             0.066538   93.146604   -3.373424    9.025255 -0.9
# 2708             0.067060   93.065096    1.928855    9.803983 -0.9
# ...

# %%
file2=folder2+"/"+"test04.csv"
bd2=pd.read_csv(file2,sep="\t")
print bd2.head(5)
#bd1[bd1.ion_px_mm>95]
bd2[bd2.iloc[:,1]>93]
# Out:
#    ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  el3  \
# 0            0.070810   93.193980   -0.436783    8.356897 -0.9 -0.9 -0.9    0
# 1            0.070810   93.193980   -0.436783    8.356897 -0.9 -0.9 -0.9    0
# 2            0.068967   93.099738   -0.756718    6.494410 -0.9 -0.9 -0.9    0
# 3            0.068967   93.099738   -0.756718    6.494410 -0.9 -0.9 -0.9    0
# 4            0.067452   93.002845   -1.023799    4.950887 -0.9 -0.9 -0.9    0
#
#    el4  el5
# 0    0    2
# 1    0    2
# 2    0    3
# 3    0    3
# 4    0    4
#        ion_time_of_flight  ion_px_mm   ion_py_mm   ion_pz_mm    bx   by   bz  \
# 0                0.070810   93.193980   -0.436783    8.356897 -0.9 -0.9 -0.9
# 1                0.070810   93.193980   -0.436783    8.356897 -0.9 -0.9 -0.9
# 2                0.068967   93.099738   -0.756718    6.494410 -0.9 -0.9 -0.9
# 3                0.068967   93.099738   -0.756718    6.494410 -0.9 -0.9 -0.9
# ...
